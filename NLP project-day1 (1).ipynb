# %%
# !pip install spacy
# !pip install textract
import os
import re
import nltk
import spacy
import string
import textract
import pandas as pd
import seaborn as sns
from matplotlib import pylab
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: spacy in c:\users\naveen\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: jinja2 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (8.1.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: setuptools in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (0.10.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (1.10.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (22.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (2.4.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (2.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\naveen\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\naveen\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naveen\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\naveen\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\naveen\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\naveen\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\naveen\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\naveen\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.10)
# Requirement already satisfied: colorama in c:\users\naveen\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\naveen\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\naveen\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\naveen\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naveen\anaconda3\lib\site-packages)
# Requirement already satisfied: textract in c:\users\naveen\anaconda3\lib\site-packages (1.6.5)
# Requirement already satisfied: docx2txt~=0.8 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (0.8)
# Requirement already satisfied: pdfminer.six==20191110 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (20191110)
# Requirement already satisfied: extract-msg<=0.29.* in c:\users\naveen\anaconda3\lib\site-packages (from textract) (0.28.7)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (3.8.1)
# Requirement already satisfied: argcomplete~=1.10.0 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (1.10.3)
# Requirement already satisfied: six~=1.12.0 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (1.12.0)
# Requirement already satisfied: xlrd~=1.2.0 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (1.2.0)
# Requirement already satisfied: python-pptx~=0.6.18 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (0.6.22)
# Requirement already satisfied: chardet==3.* in c:\users\naveen\anaconda3\lib\site-packages (from textract) (3.0.4)
# Requirement already satisfied: beautifulsoup4~=4.8.0 in c:\users\naveen\anaconda3\lib\site-packages (from textract) (4.8.2)
# Requirement already satisfied: pycryptodome in c:\users\naveen\anaconda3\lib\site-packages (from pdfminer.six==20191110->textract) (3.18.0)
# Requirement already satisfied: sortedcontainers in c:\users\naveen\anaconda3\lib\site-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\naveen\anaconda3\lib\site-packages (from beautifulsoup4~=4.8.0->textract) (2.3.2.post1)
# Requirement already satisfied: compressed-rtf>=1.0.6 in c:\users\naveen\anaconda3\lib\site-packages (from extract-msg<=0.29.*->textract) (1.0.6)
# Requirement already satisfied: imapclient==2.1.0 in c:\users\naveen\anaconda3\lib\site-packages (from extract-msg<=0.29.*->textract) (2.1.0)
# Requirement already satisfied: tzlocal>=2.1 in c:\users\naveen\anaconda3\lib\site-packages (from extract-msg<=0.29.*->textract) (4.2)
# Requirement already satisfied: olefile>=0.46 in c:\users\naveen\anaconda3\lib\site-packages (from extract-msg<=0.29.*->textract) (0.46)
# Requirement already satisfied: ebcdic>=1.1.1 in c:\users\naveen\anaconda3\lib\site-packages (from extract-msg<=0.29.*->textract) (1.1.1)
# Requirement already satisfied: Pillow<=9.5.0,>=3.3.2 in c:\users\naveen\anaconda3\lib\site-packages (from python-pptx~=0.6.18->textract) (9.3.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in c:\users\naveen\anaconda3\lib\site-packages (from python-pptx~=0.6.18->textract) (3.0.3)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\naveen\anaconda3\lib\site-packages (from python-pptx~=0.6.18->textract) (4.9.2)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\naveen\anaconda3\lib\site-packages (from tzlocal>=2.1->extract-msg<=0.29.*->textract) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\naveen\anaconda3\lib\site-packages (from tzlocal>=2.1->extract-msg<=0.29.*->textract) (2022.6)

# %%
os.listdir('C:\\Users\\NAVEEN\\Downloads\\Resume Docx\\Resumes')
# Out:
# ['Peoplesoft resumes',
#  'Reactjs Developer',
#  'SQL Developer Lightning insight',
#  'workday resumes']

# %%
file_path1 = []
category1  = []
directory1 = 'C:\\Users\\NAVEEN\\Downloads\\Resume Docx\\Resumes\\PeopleSoft resumes/'
for i in os.listdir(directory1):
    if i.endswith('.docx'):
        os.path.join(directory1, i)
        file_path1.append((textract.process(os.path.join(directory1, i))).decode('utf-8'))
        category1.append('PeopleSoft resumes')

# %%
df1 = pd.DataFrame(data = file_path1 , columns = ['Raw_Details'])
df1['Category1'] = category1
df1
# Out:
#                                          Raw_Details           Category1
# 0  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  PeopleSoft resumes
# 1  Classification: Internal\n\nClassification: In...  PeopleSoft resumes
# 2  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  PeopleSoft resumes
# 3  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  PeopleSoft resumes
# 4  PeopleSoft Administration\n\n \n\nVivekanand S...  PeopleSoft resumes
# 5  Hari Narayana \t\t              \n\n\t\n\n\n\n...  PeopleSoft resumes
# 6  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  PeopleSoft resumes
# 7  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  PeopleSoft resumes
# 8  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  PeopleSoft resumes
# 9  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  PeopleSoft resumes

# %%
file_path2 = []
category2  = []
directory2 = 'C:\\Users\\NAVEEN\\Downloads\\Resume Docx\\Resumes\\Reactjs Developer/'
for i in os.listdir(directory2):
    if i.endswith('.docx'):
        os.path.join(directory2, i)
        file_path2.append((textract.process(os.path.join(directory2, i))).decode('utf-8'))
        category2.append('Reactjs Developer')

# %%
df2 = pd.DataFrame(data = file_path2 , columns = ['Raw_Details'])
df2['Category2'] = category2
df2
# Out:
#                                           Raw_Details          Category2
# 0   Name: Ravali P \n\n\n\n                       ...  Reactjs Developer
# 1   SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Reactjs Developer
# 2   Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  Reactjs Developer
# 3   HARIPRIYA BATTINA \n\nExperience as UI Develop...  Reactjs Developer
# 4   KAMALAKAR REDDY. A \n\nLinked In: https://www....  Reactjs Developer
# 5   Naveen Sadhu\n\n\n\n\n\nTitle: software develo...  Reactjs Developer
# 6   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...  Reactjs Developer
# 7   SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...  Reactjs Developer
# 8   Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...  Reactjs Developer
# 9   Ui-Developer/ React JS Developer \n\nNAME: KRI...  Reactjs Developer
# 10  Ui-Developer/ React JS Developer \n\nNAME: KRI...  Reactjs Developer
# 11  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...  Reactjs Developer
# 12  Venkatalakshmi Pedireddy\n\nSoftware Developer...  Reactjs Developer
# 13  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...  Reactjs Developer
# 14  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...  Reactjs Developer
# 15  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...  Reactjs Developer
# 16  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...  Reactjs Developer
# 17  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...  Reactjs Developer
# 18  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...  Reactjs Developer
# 19  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...  Reactjs Developer

# %%
file_path3 = []
category3 = []
directory3 = 'C:\\Users\\NAVEEN\\Downloads\\Resume Docx\\Resumes\\SQL Developer Lightning insight/'
for i in os.listdir(directory3):
    if i.endswith('.docx'):
        os.path.join(directory3, i)
        file_path3.append((textract.process(os.path.join(directory3, i))).decode('utf-8'))
        category3.append('SQL Developer Lightning insight')

# %%
df3 = pd.DataFrame(data = file_path3 , columns = ['Raw_Details'])
df3['Category3'] = category3
df3
# Out:
#                                           Raw_Details  \
# 0   ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 1   Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 2   BUDDHA VAMSI                                  ...
# 3   KAMBALLA PRADEEP                              ...
# 4   Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 5   SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 6   SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 7   RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 8   resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 9   Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 10  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
#
#                           Category3
# 0   SQL Developer Lightning insight
# 1   SQL Developer Lightning insight
# 2   SQL Developer Lightning insight
# 3   SQL Developer Lightning insight
# 4   SQL Developer Lightning insight
# 5   SQL Developer Lightning insight
# 6   SQL Developer Lightning insight
# 7   SQL Developer Lightning insight
# 8   SQL Developer Lightning insight
# 9   SQL Developer Lightning insight
# 10  SQL Developer Lightning insight

# %%
file_path4 = []
category4 = []
directory4 = 'C:\\Users\\NAVEEN\\Downloads\\Resume Docx\\Resumes\\workday resumes/'
for i in os.listdir(directory4):
    if i.endswith('.docx'):
        os.path.join(directory4, i)
        file_path4.append((textract.process(os.path.join(directory4, i))).decode('utf-8'))
        category4.append('workday resumes')

# %%
df4 = pd.DataFrame(data = file_path4 , columns = ['Raw_Details'])
df4['Category4'] = category4
df4
# Out:
#                                           Raw_Details        Category4
# 0   Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...  workday resumes
# 1   Name         : Gopi Krishna Reddy\n\n\t\t     ...  workday resumes
# 2   G Himaja\n\n                                  ...  workday resumes
# 3   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...  workday resumes
# 4   Mooraboyina Guravaiah\n\nWorkday Integration S...  workday resumes
# 5   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...  workday resumes
# 6   Workday HCM  Techno functional Consultant     ...  workday resumes
# 7   Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...  workday resumes
# 8   Srikanth (WORKDAY hCM Consultant)\t           ...  workday resumes
# 9   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...  workday resumes
# 10  Vinay kumar .v\nWorkday Functional Consultant\...  workday resumes

# %%
resume_data = df1.append([df2, df3, df4], ignore_index = True)
resume_data
# Out:
#                                           Raw_Details           Category1  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  PeopleSoft resumes
# 1   Classification: Internal\n\nClassification: In...  PeopleSoft resumes
# 2   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  PeopleSoft resumes
# 3   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  PeopleSoft resumes
# 4   PeopleSoft Administration\n\n \n\nVivekanand S...  PeopleSoft resumes
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...  PeopleSoft resumes
# 6   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  PeopleSoft resumes
# 7   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  PeopleSoft resumes
# 8   Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  PeopleSoft resumes
# 9   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  PeopleSoft resumes
# 10  Name: Ravali P \n\n\n\n                       ...                 NaN
# 11  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...                 NaN
# 12  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...                 NaN
# 13  HARIPRIYA BATTINA \n\nExperience as UI Develop...                 NaN
# 14  KAMALAKAR REDDY. A \n\nLinked In: https://www....                 NaN
# 15  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...                 NaN
# 16  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...                 NaN
# 17  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...                 NaN
# 18  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...                 NaN
# 19  Ui-Developer/ React JS Developer \n\nNAME: KRI...                 NaN
# 20  Ui-Developer/ React JS Developer \n\nNAME: KRI...                 NaN
# 21  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...                 NaN
# 22  Venkatalakshmi Pedireddy\n\nSoftware Developer...                 NaN
# 23  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...                 NaN
# 24  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...                 NaN
# 25  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...                 NaN
# 26  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...                 NaN
# 27  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...                 NaN
# 28  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...                 NaN
# 29  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...                 NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...                 NaN
# 31  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...                 NaN
# 32  BUDDHA VAMSI                                  ...                 NaN
# 33  KAMBALLA PRADEEP                              ...                 NaN
# 34  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...                 NaN
# 35  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...                 NaN
# 36  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...                 NaN
# 37  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...                 NaN
# 38  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...                 NaN
# 39  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...                 NaN
# 40  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...                 NaN
# 41  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...                 NaN
# 42  Name         : Gopi Krishna Reddy\n\n\t\t     ...                 NaN
# 43  G Himaja\n\n                                  ...                 NaN
# 44  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...                 NaN
# 45  Mooraboyina Guravaiah\n\nWorkday Integration S...                 NaN
# 46  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...                 NaN
# 47  Workday HCM  Techno functional Consultant     ...                 NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...                 NaN
# 49  Srikanth (WORKDAY hCM Consultant)\t           ...                 NaN
# 50  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...                 NaN
# 51  Vinay kumar .v\nWorkday Functional Consultant\...                 NaN
#
#             Category2                        Category3        Category4
# 0                 NaN                              NaN              NaN
# 1                 NaN                              NaN              NaN
# 2                 NaN                              NaN              NaN
# 3                 NaN                              NaN              NaN
# 4                 NaN                              NaN              NaN
# 5                 NaN                              NaN              NaN
# 6                 NaN                              NaN              NaN
# 7                 NaN                              NaN              NaN
# 8                 NaN                              NaN              NaN
# 9                 NaN                              NaN              NaN
# 10  Reactjs Developer                              NaN              NaN
# 11  Reactjs Developer                              NaN              NaN
# 12  Reactjs Developer                              NaN              NaN
# 13  Reactjs Developer                              NaN              NaN
# 14  Reactjs Developer                              NaN              NaN
# 15  Reactjs Developer                              NaN              NaN
# 16  Reactjs Developer                              NaN              NaN
# 17  Reactjs Developer                              NaN              NaN
# 18  Reactjs Developer                              NaN              NaN
# 19  Reactjs Developer                              NaN              NaN
# 20  Reactjs Developer                              NaN              NaN
# 21  Reactjs Developer                              NaN              NaN
# 22  Reactjs Developer                              NaN              NaN
# 23  Reactjs Developer                              NaN              NaN
# 24  Reactjs Developer                              NaN              NaN
# 25  Reactjs Developer                              NaN              NaN
# 26  Reactjs Developer                              NaN              NaN
# 27  Reactjs Developer                              NaN              NaN
# 28  Reactjs Developer                              NaN              NaN
# 29  Reactjs Developer                              NaN              NaN
# 30                NaN  SQL Developer Lightning insight              NaN
# 31                NaN  SQL Developer Lightning insight              NaN
# 32                NaN  SQL Developer Lightning insight              NaN
# 33                NaN  SQL Developer Lightning insight              NaN
# 34                NaN  SQL Developer Lightning insight              NaN
# 35                NaN  SQL Developer Lightning insight              NaN
# 36                NaN  SQL Developer Lightning insight              NaN
# 37                NaN  SQL Developer Lightning insight              NaN
# 38                NaN  SQL Developer Lightning insight              NaN
# 39                NaN  SQL Developer Lightning insight              NaN
# 40                NaN  SQL Developer Lightning insight              NaN
# 41                NaN                              NaN  workday resumes
# 42                NaN                              NaN  workday resumes
# 43                NaN                              NaN  workday resumes
# 44                NaN                              NaN  workday resumes
# 45                NaN                              NaN  workday resumes
# 46                NaN                              NaN  workday resumes
# 47                NaN                              NaN  workday resumes
# 48                NaN                              NaN  workday resumes
# 49                NaN                              NaN  workday resumes
# 50                NaN                              NaN  workday resumes
# 51                NaN                              NaN  workday resumes

# %%
resume_data['Category'] = category1+category2 + category3 + category4
resume_data
# Out:
#                                           Raw_Details           Category1  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  PeopleSoft resumes
# 1   Classification: Internal\n\nClassification: In...  PeopleSoft resumes
# 2   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  PeopleSoft resumes
# 3   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  PeopleSoft resumes
# 4   PeopleSoft Administration\n\n \n\nVivekanand S...  PeopleSoft resumes
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...  PeopleSoft resumes
# 6   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  PeopleSoft resumes
# 7   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  PeopleSoft resumes
# 8   Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  PeopleSoft resumes
# 9   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  PeopleSoft resumes
# 10  Name: Ravali P \n\n\n\n                       ...                 NaN
# 11  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...                 NaN
# 12  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...                 NaN
# 13  HARIPRIYA BATTINA \n\nExperience as UI Develop...                 NaN
# 14  KAMALAKAR REDDY. A \n\nLinked In: https://www....                 NaN
# 15  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...                 NaN
# 16  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...                 NaN
# 17  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...                 NaN
# 18  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...                 NaN
# 19  Ui-Developer/ React JS Developer \n\nNAME: KRI...                 NaN
# 20  Ui-Developer/ React JS Developer \n\nNAME: KRI...                 NaN
# 21  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...                 NaN
# 22  Venkatalakshmi Pedireddy\n\nSoftware Developer...                 NaN
# 23  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...                 NaN
# 24  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...                 NaN
# 25  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...                 NaN
# 26  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...                 NaN
# 27  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...                 NaN
# 28  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...                 NaN
# 29  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...                 NaN
# 30  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...                 NaN
# 31  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...                 NaN
# 32  BUDDHA VAMSI                                  ...                 NaN
# 33  KAMBALLA PRADEEP                              ...                 NaN
# 34  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...                 NaN
# 35  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...                 NaN
# 36  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...                 NaN
# 37  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...                 NaN
# 38  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...                 NaN
# 39  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...                 NaN
# 40  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...                 NaN
# 41  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...                 NaN
# 42  Name         : Gopi Krishna Reddy\n\n\t\t     ...                 NaN
# 43  G Himaja\n\n                                  ...                 NaN
# 44  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...                 NaN
# 45  Mooraboyina Guravaiah\n\nWorkday Integration S...                 NaN
# 46  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...                 NaN
# 47  Workday HCM  Techno functional Consultant     ...                 NaN
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...                 NaN
# 49  Srikanth (WORKDAY hCM Consultant)\t           ...                 NaN
# 50  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...                 NaN
# 51  Vinay kumar .v\nWorkday Functional Consultant\...                 NaN
#
#             Category2                        Category3        Category4  \
# 0                 NaN                              NaN              NaN
# 1                 NaN                              NaN              NaN
# 2                 NaN                              NaN              NaN
# 3                 NaN                              NaN              NaN
# 4                 NaN                              NaN              NaN
# 5                 NaN                              NaN              NaN
# 6                 NaN                              NaN              NaN
# 7                 NaN                              NaN              NaN
# 8                 NaN                              NaN              NaN
# 9                 NaN                              NaN              NaN
# 10  Reactjs Developer                              NaN              NaN
# 11  Reactjs Developer                              NaN              NaN
# 12  Reactjs Developer                              NaN              NaN
# 13  Reactjs Developer                              NaN              NaN
# 14  Reactjs Developer                              NaN              NaN
# 15  Reactjs Developer                              NaN              NaN
# 16  Reactjs Developer                              NaN              NaN
# 17  Reactjs Developer                              NaN              NaN
# 18  Reactjs Developer                              NaN              NaN
# 19  Reactjs Developer                              NaN              NaN
# 20  Reactjs Developer                              NaN              NaN
# 21  Reactjs Developer                              NaN              NaN
# 22  Reactjs Developer                              NaN              NaN
# 23  Reactjs Developer                              NaN              NaN
# 24  Reactjs Developer                              NaN              NaN
# 25  Reactjs Developer                              NaN              NaN
# 26  Reactjs Developer                              NaN              NaN
# 27  Reactjs Developer                              NaN              NaN
# 28  Reactjs Developer                              NaN              NaN
# 29  Reactjs Developer                              NaN              NaN
# 30                NaN  SQL Developer Lightning insight              NaN
# 31                NaN  SQL Developer Lightning insight              NaN
# 32                NaN  SQL Developer Lightning insight              NaN
# 33                NaN  SQL Developer Lightning insight              NaN
# 34                NaN  SQL Developer Lightning insight              NaN
# 35                NaN  SQL Developer Lightning insight              NaN
# 36                NaN  SQL Developer Lightning insight              NaN
# 37                NaN  SQL Developer Lightning insight              NaN
# 38                NaN  SQL Developer Lightning insight              NaN
# 39                NaN  SQL Developer Lightning insight              NaN
# 40                NaN  SQL Developer Lightning insight              NaN
# 41                NaN                              NaN  workday resumes
# 42                NaN                              NaN  workday resumes
# 43                NaN                              NaN  workday resumes
# 44                NaN                              NaN  workday resumes
# 45                NaN                              NaN  workday resumes
# 46                NaN                              NaN  workday resumes
# 47                NaN                              NaN  workday resumes
# 48                NaN                              NaN  workday resumes
# 49                NaN                              NaN  workday resumes
# 50                NaN                              NaN  workday resumes
# 51                NaN                              NaN  workday resumes
#
#                            Category
# 0                PeopleSoft resumes
# 1                PeopleSoft resumes
# 2                PeopleSoft resumes
# 3                PeopleSoft resumes
# 4                PeopleSoft resumes
# 5                PeopleSoft resumes
# 6                PeopleSoft resumes
# 7                PeopleSoft resumes
# 8                PeopleSoft resumes
# 9                PeopleSoft resumes
# 10                Reactjs Developer
# 11                Reactjs Developer
# 12                Reactjs Developer
# 13                Reactjs Developer
# 14                Reactjs Developer
# 15                Reactjs Developer
# 16                Reactjs Developer
# 17                Reactjs Developer
# 18                Reactjs Developer
# 19                Reactjs Developer
# 20                Reactjs Developer
# 21                Reactjs Developer
# 22                Reactjs Developer
# 23                Reactjs Developer
# 24                Reactjs Developer
# 25                Reactjs Developer
# 26                Reactjs Developer
# 27                Reactjs Developer
# 28                Reactjs Developer
# 29                Reactjs Developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes

# %%
resume_data.drop(['Category1', 'Category2', 'Category3', 'Category4'], axis=1, inplace=True)
resume_data
# Out:
#                                           Raw_Details  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1   Classification: Internal\n\nClassification: In...
# 2   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 3   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 4   PeopleSoft Administration\n\n \n\nVivekanand S...
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 6   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 7   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 8   Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 9   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 10  Name: Ravali P \n\n\n\n                       ...
# 11  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 12  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 13  HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 14  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 15  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 16  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 17  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 18  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 19  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 20  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 21  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 22  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 23  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 24  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 25  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 26  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 27  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 28  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 29  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 30  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 31  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 32  BUDDHA VAMSI                                  ...
# 33  KAMBALLA PRADEEP                              ...
# 34  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 35  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 36  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 37  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 38  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 39  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 40  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 41  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 42  Name         : Gopi Krishna Reddy\n\n\t\t     ...
# 43  G Himaja\n\n                                  ...
# 44  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 45  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 46  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 47  Workday HCM  Techno functional Consultant     ...
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 49  Srikanth (WORKDAY hCM Consultant)\t           ...
# 50  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 51  Vinay kumar .v\nWorkday Functional Consultant\...
#
#                            Category
# 0                PeopleSoft resumes
# 1                PeopleSoft resumes
# 2                PeopleSoft resumes
# 3                PeopleSoft resumes
# 4                PeopleSoft resumes
# 5                PeopleSoft resumes
# 6                PeopleSoft resumes
# 7                PeopleSoft resumes
# 8                PeopleSoft resumes
# 9                PeopleSoft resumes
# 10                Reactjs Developer
# 11                Reactjs Developer
# 12                Reactjs Developer
# 13                Reactjs Developer
# 14                Reactjs Developer
# 15                Reactjs Developer
# 16                Reactjs Developer
# 17                Reactjs Developer
# 18                Reactjs Developer
# 19                Reactjs Developer
# 20                Reactjs Developer
# 21                Reactjs Developer
# 22                Reactjs Developer
# 23                Reactjs Developer
# 24                Reactjs Developer
# 25                Reactjs Developer
# 26                Reactjs Developer
# 27                Reactjs Developer
# 28                Reactjs Developer
# 29                Reactjs Developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes

# %%
resume_data.isnull().sum()
# Out:
# Raw_Details    0
# Category       0
# dtype: int64

# %%
resume_data.to_csv('Raw_Resume.csv', index=False)

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#                                           Raw_Details  \
# 0   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 1   Classification: Internal\n\nClassification: In...
# 2   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 3   PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...
# 4   PeopleSoft Administration\n\n \n\nVivekanand S...
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 6   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 7   Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 8   Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 9   C O N T A C T :\n\n\n\nAddress: Manyata Tech P...
# 10  Name: Ravali P \n\n\n\n                       ...
# 11  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
# 12  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...
# 13  HARIPRIYA BATTINA \n\nExperience as UI Develop...
# 14  KAMALAKAR REDDY. A \n\nLinked In: https://www....
# 15  Naveen Sadhu\n\n\n\n\n\nTitle: software develo...
# 16  PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...
# 17  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...
# 18  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...
# 19  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 20  Ui-Developer/ React JS Developer \n\nNAME: KRI...
# 21  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...
# 22  Venkatalakshmi Pedireddy\n\nSoftware Developer...
# 23  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...
# 24  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...
# 25  MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...
# 26  MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...
# 27  Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...
# 28  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...
# 29  SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...
# 30  ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...
# 31  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...
# 32  BUDDHA VAMSI                                  ...
# 33  KAMBALLA PRADEEP                              ...
# 34  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...
# 35  SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...
# 36  SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...
# 37  RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...
# 38  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...
# 39  Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...
# 40  SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...
# 41  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 42  Name         : Gopi Krishna Reddy\n\n\t\t     ...
# 43  G Himaja\n\n                                  ...
# 44  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 45  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 46  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 47  Workday HCM  Techno functional Consultant     ...
# 48  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 49  Srikanth (WORKDAY hCM Consultant)\t           ...
# 50  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 51  Vinay kumar .v\nWorkday Functional Consultant\...
#
#                            Category
# 0                PeopleSoft resumes
# 1                PeopleSoft resumes
# 2                PeopleSoft resumes
# 3                PeopleSoft resumes
# 4                PeopleSoft resumes
# 5                PeopleSoft resumes
# 6                PeopleSoft resumes
# 7                PeopleSoft resumes
# 8                PeopleSoft resumes
# 9                PeopleSoft resumes
# 10                Reactjs Developer
# 11                Reactjs Developer
# 12                Reactjs Developer
# 13                Reactjs Developer
# 14                Reactjs Developer
# 15                Reactjs Developer
# 16                Reactjs Developer
# 17                Reactjs Developer
# 18                Reactjs Developer
# 19                Reactjs Developer
# 20                Reactjs Developer
# 21                Reactjs Developer
# 22                Reactjs Developer
# 23                Reactjs Developer
# 24                Reactjs Developer
# 25                Reactjs Developer
# 26                Reactjs Developer
# 27                Reactjs Developer
# 28                Reactjs Developer
# 29                Reactjs Developer
# 30  SQL Developer Lightning insight
# 31  SQL Developer Lightning insight
# 32  SQL Developer Lightning insight
# 33  SQL Developer Lightning insight
# 34  SQL Developer Lightning insight
# 35  SQL Developer Lightning insight
# 36  SQL Developer Lightning insight
# 37  SQL Developer Lightning insight
# 38  SQL Developer Lightning insight
# 39  SQL Developer Lightning insight
# 40  SQL Developer Lightning insight
# 41                  workday resumes
# 42                  workday resumes
# 43                  workday resumes
# 44                  workday resumes
# 45                  workday resumes
# 46                  workday resumes
# 47                  workday resumes
# 48                  workday resumes
# 49                  workday resumes
# 50                  workday resumes
# 51                  workday resumes

# %%
resume_data.isnull().sum()
# Out:
# Raw_Details     0
# Category1      42
# Category2      32
# Category3      41
# Category4      41
# Category        0
# dtype: int64
